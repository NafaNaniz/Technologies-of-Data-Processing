# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %% [markdown]
# ## Лабораторная работа №2

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
recipes = pd.read_csv('recipes_sample.csv', delimiter=',')
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %%
reviews = pd.read_csv('reviews_sample.csv', delimiter=',', index_col=0)
reviews
# Out:
#             user_id  recipe_id        date  rating  \
# 370476        21752      57993  2003-05-01       5
# 624300       431813     142201  2007-09-16       5
# 187037       400708     252013  2008-01-10       4
# 706134   2001852463     404716  2017-12-11       5
# 312179        95810     129396  2008-03-14       5
# ...             ...        ...         ...     ...
# 1013457     1270706     335534  2009-05-17       4
# 158736      2282344       8701  2012-06-03       0
# 1059834      689540     222001  2008-04-08       5
# 453285   2000242659     354979  2015-06-02       5
# 691207       463435     415599  2010-09-30       5
#
#                                                     review
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
count_row_recipes = recipes.shape[0]  # Gives number of rows
count_col_recipes = recipes.shape[1]  # Gives number of columns
print(f'Recipes: количество точек данных (строк) для - {count_row_recipes}, количество столбцов - {count_col_recipes}, \nтипы данных столбцов: \n{recipes.dtypes}')
count_row_reviews = reviews.shape[0]  # Gives number of rows
count_col_reviews = reviews.shape[1]  # Gives number of columns
print(f'Reviews: количество точек данных (строк) для - {count_row_reviews}, количество столбцов - {count_col_reviews}, \nтипы данных столбцов: \n{reviews.dtypes}')
# Out:
# Recipes: количество точек данных (строк) для - 30000, количество столбцов - 8,
# типы данных столбцов:
# name               object
# id                  int64
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object
# Reviews: количество точек данных (строк) для - 126696, количество столбцов - 5,
# типы данных столбцов:
# user_id       int64
# recipe_id     int64
# date         object
# rating        int64
# review       object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
recipes_non = recipes.isna().sum()
print(f'{((recipes.shape[0] - recipes.dropna(axis=0).shape[0])/recipes.shape[0])*100}%')
print(f'Столбцы с пропусками: {recipes_non[recipes_non>0].index}')
reviews_non = reviews.isna().sum()
print(f'{((reviews.shape[0] - reviews.dropna(axis=0).shape[0])/reviews.shape[0])*100}%')
print(f'Столбцы с пропусками: {reviews_non[reviews_non>0].index}')
# Out:
# 56.846666666666664%
# Столбцы с пропусками: Index(['n_steps', 'description', 'n_ingredients'], dtype='object')
# 0.013417945317926377%
# Столбцы с пропусками: Index(['review'], dtype='object')

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
print(recipes[['id', 'minutes', 'contributor_id', 'n_steps', 'n_ingredients']].mean(), end = '\n\n')
print(reviews[['user_id', 'recipe_id', 'rating']].mean())
# Out:
# id                2.218793e+05
# minutes           1.233581e+02
# contributor_id    5.635901e+06
# n_steps           9.805582e+00
# n_ingredients     9.008286e+00
# dtype: float64
#
# user_id      1.408013e+08
# recipe_id    1.600944e+05
# rating       4.410802e+00
# dtype: float64

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
recipes_random = recipes.sample(n = 10)
recipes_random
# Out:
#                                         name      id  minutes  contributor_id  \
# 1786                  baked chicken drummies  495338       45          329769
# 5522                   chicken   rice supper  127253       50          171854
# 11066                    fishermans sandwich  269017       30          644902
# 16746         mahi mahi with pineapple salsa  314811       25          305531
# 28718  vegetarian enchilada casserole recipe  451098       60          542159
# 13120                  guacamole quesadillas  295975       20          446738
# 3817                   broccoli eggs supreme  229065      132          169430
# 14958                    jelly sauce for ham  130816        2          207176
# 19493          oriental style salmon fillets  484545       13          280271
# 793                 apple   hazelnut crumble  293253       65          795961
#
#         submitted  n_steps                                        description  \
# ...

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
indexes = list(range(len(reviews)))
reviews.index = indexes
reviews
# Out:
#            user_id  recipe_id        date  rating  \
# 0            21752      57993  2003-05-01       5
# 1           431813     142201  2007-09-16       5
# 2           400708     252013  2008-01-10       4
# 3       2001852463     404716  2017-12-11       5
# 4            95810     129396  2008-03-14       5
# ...            ...        ...         ...     ...
# 126691     1270706     335534  2009-05-17       4
# 126692     2282344       8701  2012-06-03       0
# 126693      689540     222001  2008-04-08       5
# 126694  2000242659     354979  2015-06-02       5
# 126695      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# 3       These are a favorite for the holidays and so e...
# 4       Excellent soup!  The tomato flavor is just gre...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
recipes[(recipes.minutes <=20) & (recipes.n_ingredients <= 5)]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes['submitted'] = pd.to_datetime(recipes['submitted'])
recipes['submitted']
# Out:
# 0       2002-10-25
# 1       2003-07-26
# 2       2002-08-29
# 3       2002-07-27
# 4       2004-02-23
#            ...
# 29995   2007-11-25
# 29996   2009-08-24
# 29997   2004-11-03
# 29998   2012-08-29
# 29999   2008-04-15
# Name: submitted, Length: 30000, dtype: datetime64[ns]

# %%
recipess = pd.read_csv('recipes_sample.csv', delimiter=',', parse_dates=['submitted'])
recipess['submitted']
# Out:
# 0       2002-10-25
# 1       2003-07-26
# 2       2002-08-29
# 3       2002-07-27
# 4       2004-02-23
#            ...
# 29995   2007-11-25
# 29996   2009-08-24
# 29997   2004-11-03
# 29998   2012-08-29
# 29999   2008-04-15
# Name: submitted, Length: 30000, dtype: datetime64[ns]

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes[recipes.submitted < '2011-01-01']
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes['description_length'] = recipes['description'].str.len()
task_6 = recipes
recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes['name'] = recipes['name'].str.title()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
recipes['name_word_count'] = recipes['name'].str.split().str.len()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George S At The Cove  Black Bean Soup   44123       90
# 1                Healthy For Them  Yogurt Popsicles   67664       10
# 2                      I Can T Believe It S Spinach   38798       30
# 3                              Italian  Gut Busters   35173       45
# 4          Love Is In The Air  Beef Fondue   Sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie S Holey Rustic Olive And Cheddar Bread  267661       80
# 29996          Zwetschgenkuchen  Bavarian Plum Cake  386977      240
# 29997   Zwiebelkuchen   Southwest German Onion Cake  103312       75
# 29998                                   Zydeco Soup  486161       60
# 29999        Cookies By Design   Cookies On A Stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
c = recipes.groupby('contributor_id')
print(c.count().idxmax().name_word_count)
c.count()
# Out:
# 89831
#                 name   id  minutes  submitted  n_steps  description  \
# contributor_id
# 1530               5    5        5          5        2            2
# 1533             186  186      186        186      114           70
# 1534              50   50       50         50       27           15
# 1535              40   40       40         40       21           38
# 1538               8    8        8          8        5            3
# ...              ...  ...      ...        ...      ...          ...
# 2001968497         2    2        2          2        0            2
# 2002059754         1    1        1          1        1            1
# 2002234079         1    1        1          1        1            1
# 2002234259         1    1        1          1        1            1
# 2002247884         1    1        1          1        1            1
#
#                 n_ingredients  description_length  name_word_count
# contributor_id
# ...

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
rating = reviews.groupby('recipe_id')['rating'].mean()
rating
# Out:
# recipe_id
# 48        1.000000
# 55        4.750000
# 66        4.944444
# 91        4.750000
# 94        5.000000
#             ...
# 536547    5.000000
# 536610    0.000000
# 536728    4.000000
# 536729    4.750000
# 536747    0.000000
# Name: rating, Length: 28100, dtype: float64

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
c = recipes.groupby(pd.Grouper(key='submitted', freq="Y"))
c.count()['name_word_count']
# Out:
# submitted
# 1999-12-31     275
# 2000-12-31     104
# 2001-12-31     589
# 2002-12-31    2644
# 2003-12-31    2334
# 2004-12-31    2153
# 2005-12-31    3130
# 2006-12-31    3473
# 2007-12-31    4429
# 2008-12-31    4029
# 2009-12-31    2963
# 2010-12-31    1538
# 2011-12-31     922
# 2012-12-31     659
# 2013-12-31     490
# 2014-12-31     139
# 2015-12-31      42
# 2016-12-31      24
# 2017-12-31      39
# 2018-12-31      24
# Freq: A-DEC, Name: name_word_count, dtype: int64

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
combined_table = recipes.merge(reviews, left_on='id', right_on='recipe_id', how='inner')
combined_table = combined_table[['id', 'name', 'user_id', 'rating']]
task_5_1 = combined_table
combined_table
# Out:
#             id                                               name     user_id  \
# 0        77188  Subru Uncle S Whole Green Moong Dal I Ll Be Ma...      184447
# 1        77188  Subru Uncle S Whole Green Moong Dal I Ll Be Ma...      668205
# 2        77188  Subru Uncle S Whole Green Moong Dal I Ll Be Ma...      843746
# 3        77188  Subru Uncle S Whole Green Moong Dal I Ll Be Ma...      507469
# 4        77188  Subru Uncle S Whole Green Moong Dal I Ll Be Ma...      719941
# ...        ...                                                ...         ...
# 126691  143615                                           Caramels     1425430
# 126692  143615                                           Caramels      136558
# 126693  143615                                           Caramels  1800106861
# 126694  143615                                           Caramels      302094
# 126695  143615                                           Caramels      646764
#
#         rating
# 0            4
# ...

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
combined_table = recipes.merge(reviews, left_on='id', right_on='recipe_id', how='left')
combined_table['review_count'] = combined_table.groupby('recipe_id')['review'].count()
#b = combined_table.groupby('recipe_id')['review'].count()
task_5_2 = combined_table
#combined_table = combined_table.fillna(0)
#combined_table = combined_table[['recipe_id', 'name', 'review_count']]
combined_table
b = combined_table.groupby('recipe_id')['review'].count()
print(b)
combined_table = combined_table.merge(b, on='recipe_id')
combined_table
# Out:
# recipe_id
# 48.0         2
# 55.0         4
# 66.0        18
# 91.0         4
# 94.0         4
#             ..
# 536547.0     1
# 536610.0     1
# 536728.0     1
# 536729.0     4
# 536747.0     4
# Name: review, Length: 28100, dtype: int64
#                                                      name      id  minutes  \
# 0       Subru Uncle S Whole Green Moong Dal I Ll Be Ma...   77188       95
# 1       Subru Uncle S Whole Green Moong Dal I Ll Be Ma...   77188       95
# 2       Subru Uncle S Whole Green Moong Dal I Ll Be Ma...   77188       95
# 3       Subru Uncle S Whole Green Moong Dal I Ll Be Ma...   77188       95
# 4       Subru Uncle S Whole Green Moong Dal I Ll Be Ma...   77188       95
# ...                                                   ...     ...      ...
# 126691                                           Caramels  143615       30
# 126692                                           Caramels  143615       30
# ...

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
combined_table = recipes.merge(reviews, left_on='id', right_on='recipe_id', how='inner')
combined_table = combined_table.groupby(pd.Grouper(key='submitted', freq="Y"))['rating'].mean()
combined_table[combined_table == combined_table.min()]
# Out:
# submitted
# 2017-12-31    2.75
# Freq: A-DEC, Name: rating, dtype: float64

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipes = task_6
recipes = recipes.sort_values(by='name_word_count', ascending=False)
recipes.to_csv('task6.csv')

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter("task_6_2.xlsx") as writer:
    task_5_1.to_excel(writer, sheet_name='Рецепты с оценками')  
    task_5_2.to_excel(writer, sheet_name='Количество отзывов по рецептам')
